# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Config" data-toc-modified-id="Config-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Config</a></span><ul class="toc-item"><li><span><a href="#Path" data-toc-modified-id="Path-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Path</a></span></li></ul></li><li><span><a href="#SAMPLE" data-toc-modified-id="SAMPLE-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>SAMPLE</a></span></li></ul></div>

# %% [markdown]
# ## Config

# %%
import os,pathlib
import cv2
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import sys
print(sys.version)
# Out:
# 3.6.5 (default, Jan 23 2019, 14:43:22)
# [GCC 4.2.1 Compatible Apple LLVM 10.0.0 (clang-1000.10.44.4)]

# %% [markdown]
# ### Path

# %%
HOME_Path = pathlib.Path(os.getcwd()).parents[0]
data_Path = HOME_Path / "data"
print("path name | exist | path\n" + 
      "========================")
print("HOME_Path | {:5} | {}".format(HOME_Path.exists(), str(HOME_Path)))
print("data_Path | {:5} | {}".format(data_Path.exists(), str(data_Path)))
# Out:
# path name | exist | path
# ...
# HOME_Path |     1 | /Users/hiroaki.sugisaki/workdir/git/Learning_Matplotlib_python
# data_Path |     1 | /Users/hiroaki.sugisaki/workdir/git/Learning_Matplotlib_python/data

# %% [markdown]
# ## SAMPLE

# %%
_filepath = str(data_Path / "Aerial.bmp")
im = cv2.imread(filename=_filepath)
im = cv2.cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
_h, _w, _c = im.shape
print("im.shape : {}".format(im.shape))
print("-------------------------------\n" +
      "| Height  | Width   | Channel |\n" +
      "| {:7} | {:7} | {:7} |\n".format(_h, _w, _c) +
      "-------------------------------")
# Out:
# im.shape : (256, 256, 3)
# -------------------------------
# | Height  | Width   | Channel |
# |     256 |     256 |       3 |
# -------------------------------

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(5,5))
nrows, ncols, idx = 1, 1, 0
idx += 1
ax = Axes3D(fig)
#ax = fig.add_subplot(nrows, ncols, idx, projection='3d')
ax.imshow(im)
ax.set_title(label="im.shape:{}".format(im.shape))
ax.set_xlabel(xlabel="im[1]")
ax.set_ylabel(ylabel="im[0]")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# create a 21 x 21 vertex mesh
xx, yy = np.meshgrid(np.arange(im.shape[0]),
                     np.arange(im.shape[1]))
# create vertices for a rotated mesh (3D rotation matrix)
X =  xx 
Y =  yy

# %%
"""
=======================
Plot 2D data on 3D plot
=======================

Demonstrates using ax.plot's zdir keyword to plot 2D data on
selective axes of a 3D plot.
"""

from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
#ax = fig.gca(projection='3d')
ax = Axes3D(fig)

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
#ax.plot(x, y, zs=0, zdir='z', label='curve in (x,y)')
#ax.imshow(im,
#          #cmap=plt.cm.BrBG,
#          interpolation='nearest',
#          origin='lower',
#          extent=[0,1,0,1])
ax.contourf(X, Y, im, 100, zdir='z', offset=0.5,
            cmap=)


# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')
x = np.random.sample(20*len(colors))
y = np.random.sample(20*len(colors))
#c_list = []
#for c in colors:
#    c_list.append([c]*20)
## By using zdir='y', the y value of these points is fixed to the zs value 0
## and the (x,y) points are plotted on the x and z axes.
#ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x,z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35)

plt.show()
# Out:
# <div id='960381cf-39c9-4cf0-b9eb-4708b31cf8e2'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-45413573e1e4> in <module>
#      25 #          origin='lower',
#      26 #          extent=[0,1,0,1])
# ---> 27 ax.contourf(X, Y, im, 100, zdir='z', offset=0.5, cmap=plt.cm.BrBG)
#      28
#      29
#
# ~/.pyenv/versions/3.6.5/envs/Learning_Matplotlib_python/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in contourf(self, X, Y, Z, zdir, offset, *args, **kwargs)
#    2162
#    2163         jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
# -> 2164         cset = super().contourf(jX, jY, jZ, *args, **kwargs)
#    2165         self.add_contourf_set(cset, zdir, offset)
#    2166
#
# ~/.pyenv/versions/3.6.5/envs/Learning_Matplotlib_python/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...
